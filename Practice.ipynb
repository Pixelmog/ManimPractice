# %% [markdown]
# # Jupyter Notebook Example
# This is an example notebook

# %%
print("Hello World")
# Out:
# Hello World

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.2.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.2.0-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 12.6/12.6 MB 78.1 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.0

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.3-cp313-cp313-win_amd64.whl.metadata (168 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\joshu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\joshu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joshu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\joshu\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 8.0/8.0 MB 59.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl (220 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 49.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp313-cp313-win_amd64.whl (55 kB)
# Downloading pillow-11.0.0-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 65.6 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.7 matplotlib-3.10.0 pillow-11.0.0 pyparsing-3.2.0

# %%
import numpy as np
import matplotlib.pylab as plt

t = np.arange(0.0, 2.0, 0.01)
s = 1+np.sin(2*np.pi*t)
fig, ax = plt.subplots()
ax.plot(t,s)

ax.grid()

# %%
# !pip install manim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: manim in c:\tools\manim\lib\site-packages (0.18.1)
# Requirement already satisfied: Pillow>=9.1 in c:\tools\manim\lib\site-packages (from manim) (11.0.0)
# Requirement already satisfied: Pygments>=2.0.0 in c:\tools\manim\lib\site-packages (from manim) (2.18.0)
# Requirement already satisfied: click>=8.0 in c:\tools\manim\lib\site-packages (from manim) (8.1.7)
# Requirement already satisfied: cloup>=2.0.0 in c:\tools\manim\lib\site-packages (from manim) (3.0.5)
# Requirement already satisfied: decorator>=4.3.2 in c:\tools\manim\lib\site-packages (from manim) (5.1.1)
# Requirement already satisfied: isosurfaces>=0.1.0 in c:\tools\manim\lib\site-packages (from manim) (0.1.2)
# Requirement already satisfied: manimpango<1.0.0,>=0.5.0 in c:\tools\manim\lib\site-packages (from manim) (0.6.0)
# Requirement already satisfied: mapbox-earcut>=1.0.0 in c:\tools\manim\lib\site-packages (from manim) (1.0.2)
# Requirement already satisfied: moderngl<6.0.0,>=5.0.0 in c:\tools\manim\lib\site-packages (from manim) (5.12.0)
# Requirement already satisfied: moderngl-window>=2.0.0 in c:\tools\manim\lib\site-packages (from manim) (3.0.3)
# Requirement already satisfied: networkx>=2.6 in c:\tools\manim\lib\site-packages (from manim) (3.4.2)
# Requirement already satisfied: numpy>=1.26 in c:\tools\manim\lib\site-packages (from manim) (2.2.0)
# Requirement already satisfied: pycairo<2.0.0,>=1.13 in c:\tools\manim\lib\site-packages (from manim) (1.27.0)
# Requirement already satisfied: pydub>=0.20.0 in c:\tools\manim\lib\site-packages (from manim) (0.25.1)
# Requirement already satisfied: rich>=12.0.0 in c:\tools\manim\lib\site-packages (from manim) (13.9.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\tools\manim\lib\site-packages (from manim) (1.14.1)
# Requirement already satisfied: screeninfo>=0.7 in c:\tools\manim\lib\site-packages (from manim) (0.8.1)
# Requirement already satisfied: skia-pathops>=0.7.0 in c:\tools\manim\lib\site-packages (from manim) (0.8.0.post2)
# Requirement already satisfied: srt>=3.0.0 in c:\tools\manim\lib\site-packages (from manim) (3.5.3)
# Requirement already satisfied: svgelements>=1.8.0 in c:\tools\manim\lib\site-packages (from manim) (1.9.6)
# Requirement already satisfied: tqdm>=4.0.0 in c:\tools\manim\lib\site-packages (from manim) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\tools\manim\lib\site-packages (from manim) (4.12.2)
# Requirement already satisfied: watchdog>=2.0.0 in c:\tools\manim\lib\site-packages (from manim) (6.0.0)
# Requirement already satisfied: colorama in c:\tools\manim\lib\site-packages (from click>=8.0->manim) (0.4.6)
# Requirement already satisfied: glcontext>=3.0.0 in c:\tools\manim\lib\site-packages (from moderngl<6.0.0,>=5.0.0->manim) (3.0.0)
# Requirement already satisfied: pyglet>=2.0.0 in c:\tools\manim\lib\site-packages (from moderngl-window>=2.0.0->manim) (2.0.20)
# Requirement already satisfied: pyglm<3,>=2.7.0 in c:\tools\manim\lib\site-packages (from moderngl-window>=2.0.0->manim) (2.7.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\tools\manim\lib\site-packages (from rich>=12.0.0->manim) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\tools\manim\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->manim) (0.1.2)

# %%
from manim import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from manim import *
#
# ModuleNotFoundError: No module named 'manim'
